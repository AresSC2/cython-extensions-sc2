# %% [markdown]
# ## Use this starter notebook to run some new experiments

# %%
# Change path as needed
MAP_PATH = "../tests/pickle_data/GresvanAIE.xz"

# %%
# load cell magic things
# %load_ext line_profiler
# %load_ext Cython
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# imports
import matplotlib.pyplot as plt
import numpy as np

from sc2.ids.unit_typeid import UnitTypeId
from sc2.bot_ai import BotAI
from sc2.position import Point2
from sc2.dicts.unit_trained_from import UNIT_TRAINED_FROM
from sc2.game_info import Race
from sc2.unit import Unit
from sc2.units import Units

from tests.load_bot_from_pickle import get_map_specific_bot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 9
#       7 from sc2.position import Point2
#       8 from sc2.dicts.unit_trained_from import UNIT_TRAINED_FROM
# ----> 9 from sc2.game_info import Race
#      10 from sc2.unit import Unit
#      11 from sc2.units import Units
#
# ImportError: cannot import name 'Race' from 'sc2.game_info' (C:\Users\jonas\AppData\Local\pypoetry\Cache\virtualenvs\cython-extensions-sc2-W_X1hE6H-py3.13\Lib\site-packages\sc2\game_info.py)

# %%
# setup a burnysc2 BOTAI instance we can test with
bot: BotAI = get_map_specific_bot(MAP_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # setup a burnysc2 BOTAI instance we can test with
# ----> 2 bot: BotAI = get_map_specific_bot(MAP_PATH)
#
# NameError: name 'get_map_specific_bot' is not defined

# %%
# sanity check that the bot instance is working
plt.imshow(bot.game_info.pathing_grid.data_numpy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # sanity check that the bot instance is working
# ----> 2 plt.imshow(bot.game_info.pathing_grid.data_numpy)
#
# NameError: name 'bot' is not defined

# %%
# %timeit bot.already_pending(UnitTypeId.PYLON)
